# %%
import openml as oml
import pandas as pd
import numpy as np
import os.path
from sklearn import preprocessing, ensemble

# %%
apikey = '69d4637f30ad46247c165c0cf1920f0e'
oml.config.apikey = apikey

# %%
datasets = oml.datasets.list_datasets()

# %%
datasets = pd.DataFrame(datasets)
datasets = datasets.T

# %%
datasets.columns
# Out:
# Index(['MajorityClassSize', 'MaxNominalAttDistinctValues', 'MinorityClassSize',
#        'NumberOfClasses', 'NumberOfFeatures', 'NumberOfInstances',
#        'NumberOfInstancesWithMissingValues', 'NumberOfMissingValues',
#        'NumberOfNumericFeatures', 'NumberOfSymbolicFeatures', 'did', 'format',
#        'name', 'status'],
#       dtype='object')

# %%
datasets[datasets['format'] == 'ARFF'].size
# Out:
# 257754

# %%
filtered_dataset = datasets[datasets["NumberOfFeatures"] < 20]\
                           [datasets['NumberOfNumericFeatures']>0]\
                           [datasets['NumberOfClasses'] < 20]\
                           [datasets['NumberOfInstances'] > 50]

dids = list(filtered_dataset['did'].index)
# Out:
# C:\Users\Andrea\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
final_ds = fd2[fd2['NumberOfInstances'] > 100]

# %%
def download_datasets(dids, path):
    i = 0

    for did in dids:
        try:

            if not os.path.isfile(str(did) + "-data"):
                ds = oml.datasets.get_dataset(did)
                X,y,categorical = ds.get_data(target=ds.default_target_attribute,return_categorical_indicator=True)
                np.save(path + "/" + str(did) + "-data",X)
                np.save(path + "/" + str(did) + "-target",y)
                np.save(path + "/" + str(did) + "-categorical",categorical)

        except:
            i = i+1
            print("Dataset with id " + str(did))

    print(str(i) + " datasets were impossible to download")

# %%
np.save("indexes", dids)

# %%
new_data = datasets[datasets['NumberOfClasses'] == 2]\
                   [datasets["NumberOfNumericFeatures"]>0]\
                   [datasets["MinorityClassSize"]>100]\
                   [datasets["NumberOfNumericFeatures"]<20]\
                   [datasets["NumberOfMissingValues"] < 20]
# Out:
# C:\Users\Andrea\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
new_dids = list(new_data['did'].index)

# %%
download_datasets(new_dids, "binary_problems")

# %%
datasets
# Out:
#       MajorityClassSize MaxNominalAttDistinctValues MinorityClassSize  \
# 1                   684                          10                 0
# 2                   684                           7                 8
# 3                  1669                           3              1527
# 4                    37                           3                20
# 5                   245                          13                 2
# 6                   813                          26               734
# 7                    57                           6                 1
# 8                    -1                          -1                -1
# 9                    67                          22                 3
# 10                   81                           8                 2
# 11                  288                           3                49
# 12                  200                          -1               200
# 13                  201                          11                85
# 14                  200                          10               200
# 15                  458                           2               241
# 16                  200                          -1               200
# 18                  200                          10               200
# 20                  200                           7               200
# 21                 1210                           4                65
# 22                  200                          -1               200
# 23                  629                           4               333
# 24                 4208                          12              3916
# 25                  232                          63               136
# 26                 4320                           5                 2
# 27                  232                           6               136
# 28                  572                          -1               554
# 29                  383                          14               307
# 30                 4913                          -1                28
# 31                  700                          11               300
# 32                 1144                          -1              1055
# ...                 ...                         ...               ...
# 40688                92                         NaN                14
# 40689              1655                         NaN               764
# 40690               274                         NaN               238
# 40691               681                         NaN                10
# 40692              2198                         NaN                20
# 40693               651                         NaN               322
# 40694               463                         NaN                20
# 40695               800                         NaN               800
# 40696               800                         NaN               800
# 40697               800                         NaN               800
# 40698               458                         NaN               241
# 40699               245                         NaN                68
# 40700               245                         NaN                68
# 40701              4293                         NaN               707
# 40702               884                         NaN               182
# 40703             52698                         NaN              9052
# 40704              1490                         NaN               711
# 40705               613                         NaN               346
# 40706               567                         NaN               557
# 40707              3609                         NaN                14
# 40708              3648                         NaN                34
# 40709                20                         NaN                20
# 40710               165                         NaN               138
# 40711               164                         NaN                13
# 40712               383                         NaN               307
# 40713              3714                         NaN                58
# 40714                16                         NaN                16
# 40715               500                         NaN               268
# 40753             47590                         NaN                 1
# 40869               402                         NaN               109
#
#       NumberOfClasses NumberOfFeatures NumberOfInstances  \
# 1                   6               39               898
# 2                   5               39               898
# 3                   2               37              3196
# 4                   2               17                57
# 5                  13              280               452
# 6                  26               17             20000
# 7                  24               70               226
# 8                  -1                7               345
# 9                   6               26               205
# 10                  4               19               148
# 11                  3                5               625
# 12                 10              217              2000
# 13                  2               10               286
# 14                 10               77              2000
# 15                  2               10               699
# 16                 10               65              2000
# 18                 10                7              2000
# 20                 10              241              2000
# 21                  4                7              1728
# 22                 10               48              2000
# 23                  3               10              1473
# 24                  2               23              8124
# 25                  2               28               368
# 26                  5                9             12960
# 27                  2               23               368
# 28                 10               65              5620
# 29                  2               16               690
# 30                  5               11              5473
# 31                  2               21              1000
# 32                 10               17             10992
# ...               ...              ...               ...
# 40688              18               36               675
# 40689               3               61              3188
# 40690               2               10               512
# 40691               6               12              1599
# 40692               6               12              4893
# 40693               2               10               973
# 40694               9                9              1479
# 40695               2             1001              1600
# 40696               2               21              1600
# 40697               2               21              1600
# 40698               2               11               699
# 40699               3                9               392
# 40700               3                8               392
# 40701               2               21              5000
# 40702               2               11              1066
# 40703               5               14            105908
# 40704               2                4              2201
# 40705               2               45               959
# 40706               2               11              1124
# 40707               3               30              3772
# 40708               4               30              3772
# 40709               3                4                60
# 40710               2               14               303
# 40711               5                8               303
# 40712               2               16               690
# 40713               2               30              3772
# 40714               2                6                32
# 40715               2                9               768
# 40753            4082               15           5465575
# 40869               4               17               944
#
#       NumberOfInstancesWithMissingValues NumberOfMissingValues  \
# 1                                      0                     0
# 2                                    898                 22175
# 3                                      0                     0
# 4                                     56                   326
# 5                                    384                   408
# 6                                      0                     0
# 7                                    222                   317
# 8                                      0                     0
# 9                                     46                    59
# 10                                     0                     0
# 11                                     0                     0
# 12                                     0                     0
# 13                                     9                     9
# 14                                     0                     0
# 15                                    16                    16
# 16                                     0                     0
# 18                                     0                     0
# 20                                     0                     0
# 21                                     0                     0
# 22                                     0                     0
# 23                                     0                     0
# 24                                  2480                  2480
# 25                                   361                  1927
# 26                                     0                     0
# 27                                   361                  1927
# 28                                     0                     0
# 29                                    37                    67
# 30                                     0                     0
# 31                                     0                     0
# 32                                     0                     0
# ...                                  ...                   ...
# 40688                                  0                     0
# 40689                                  0                     0
# 40690                                  0                     0
# 40691                                  0                     0
# 40692                                  0                     0
# 40693                                  0                     0
# 40694                                  0                     0
# 40695                                  0                     0
# 40696                                  0                     0
# 40697                                  0                     0
# 40698                                  0                     0
# 40699                                  0                     0
# 40700                                  0                     0
# 40701                                  0                     0
# 40702                                  0                     0
# 40703                                  0                     0
# 40704                                  0                     0
# 40705                                  0                     0
# 40706                                  0                     0
# 40707                                  0                     0
# 40708                                  0                     0
# 40709                                  0                     0
# 40710                                  0                     0
# 40711                                  0                     0
# 40712                                  0                     0
# 40713                                  0                     0
# 40714                                  0                     0
# 40715                                  0                     0
# 40753                             132617                132617
# 40869                                  0                     0
#
#       NumberOfNumericFeatures NumberOfSymbolicFeatures    did format  \
# 1                           6                       33      1   ARFF
# 2                           6                       33      2   ARFF
# 3                           0                       37      3   ARFF
# 4                           8                        9      4   ARFF
# 5                         206                       74      5   ARFF
# 6                          16                        1      6   ARFF
# 7                           0                       70      7   ARFF
# 8                           6                        1      8   ARFF
# 9                          15                       11      9   ARFF
# 10                          3                       16     10   ARFF
# 11                          4                        1     11   ARFF
# 12                        216                        1     12   ARFF
# 13                          0                       10     13   ARFF
# 14                         76                        1     14   ARFF
# 15                          9                        1     15   ARFF
# 16                         64                        1     16   ARFF
# 18                          6                        1     18   ARFF
# 20                          0                      241     20   ARFF
# 21                          0                        7     21   ARFF
# 22                         47                        1     22   ARFF
# 23                          2                        8     23   ARFF
# 24                          0                       23     24   ARFF
# 25                          7                       21     25   ARFF
# 26                          0                        9     26   ARFF
# 27                          7                       16     27   ARFF
# 28                         64                        1     28   ARFF
# 29                          6                       10     29   ARFF
# 30                         10                        1     30   ARFF
# 31                          7                       14     31   ARFF
# 32                         16                        1     32   ARFF
# ...                       ...                      ...    ...    ...
# 40688                       1                       35  40688   ARFF
# 40689                       0                       61  40689   ARFF
# 40690                       0                       10  40690   ARFF
# 40691                      11                        1  40691   ARFF
# 40692                      11                        1  40692   ARFF
# 40693                       0                       10  40693   ARFF
# 40694                       8                        1  40694   ARFF
# 40695                       0                     1001  40695   ARFF
# 40696                       0                       21  40696   ARFF
# 40697                       0                       21  40697   ARFF
# 40698                       2                        9  40698   ARFF
# 40699                       7                        2  40699   ARFF
# 40700                       6                        2  40700   ARFF
# 40701                      16                        5  40701   ARFF
# 40702                       0                       11  40702   ARFF
# 40703                      12                        2  40703   ARFF
# 40704                       3                        1  40704   ARFF
# 40705                      42                        3  40705   ARFF
# 40706                       0                       11  40706   ARFF
# 40707                       6                       24  40707   ARFF
# 40708                       6                       24  40708   ARFF
# 40709                       1                        3  40709   ARFF
# 40710                       5                        9  40710   ARFF
# 40711                       0                        8  40711   ARFF
# 40712                       7                        9  40712   ARFF
# 40713                       6                       24  40713   ARFF
# 40714                       0                        6  40714   ARFF
# 40715                       8                        1  40715   ARFF
# 40753                      11                        1  40753   ARFF
# 40869                      10                        7  40869   ARFF
#
#                                                     name  status
# 1                                                 anneal  active
# 2                                                 anneal  active
# 3                                               kr-vs-kp  active
# 4                                                  labor  active
# 5                                             arrhythmia  active
# 6                                                 letter  active
# 7                                              audiology  active
# 8                                        liver-disorders  active
# 9                                                  autos  active
# 10                                                 lymph  active
# 11                                         balance-scale  active
# 12                                         mfeat-factors  active
# 13                                         breast-cancer  active
# 14                                         mfeat-fourier  active
# 15                                              breast-w  active
# 16                                        mfeat-karhunen  active
# 18                                   mfeat-morphological  active
# 20                                           mfeat-pixel  active
# 21                                                   car  active
# 22                                         mfeat-zernike  active
# 23                                                   cmc  active
# 24                                              mushroom  active
# 25                                                 colic  active
# 26                                               nursery  active
# 27                                                 colic  active
# 28                                             optdigits  active
# 29                                              credit-a  active
# 30                                           page-blocks  active
# 31                                              credit-g  active
# 32                                             pendigits  active
# ...                                                  ...     ...
# 40688                                            soybean  active
# 40689                                             splice  active
# 40690                                           threeOf9  active
# 40691                                   wine-quality-red  active
# 40692                                 wine-quality-white  active
# 40693                                                xd6  active
# 40694                                              yeast  active
# 40695  GAMETES_Epistasis_2-Way_1000atts_0.4H_EDM-1_ED...  active
# 40696        GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1  active
# 40697        GAMETES_Epistasis_2-Way_20atts_0.4H_EDM-1_1  active
# 40698                                             breast  active
# 40699                                               cars  active
# 40700                                              cars1  active
# 40701                                              churn  active
# 40702                                              flare  active
# 40703                                              sleep  active
# 40704                                            titanic  active
# 40705                                             tokyo1  active
# 40706                                     parity5_plus_5  active
# 40707                                              allbp  active
# 40708                                             allrep  active
# 40709                              analcatdata_happiness  active
# 40710                                              cleve  active
# 40711                                  cleveland-nominal  active
# 40712                                                crx  active
# 40713                                                dis  active
# 40714                                            parity5  active
# 40715                                               pima  active
# 40753                            delays_zurich_transport  active
# 40869                            pathogen_survey_dataset  active
#
# [19593 rows x 14 columns]

# %%
ds = oml.datasets.get_dataset(195)
X,Y,Z=ds.get_data(target=ds.default_target_attribute,return_categorical_indicator=True)

# %%
from collections import Counter
Counter(Y)
# Out:
# Counter({5118: 1,
#          5151: 1,
#          5195: 1,
#          5348: 1,
#          5389: 1,
#          5399: 1,
#          5499: 1,
#          5572: 2,
#          6095: 1,
#          6189: 1,
#          6229: 2,
#          6295: 1,
#          6338: 1,
#          6377: 1,
#          6479: 1,
#          6488: 1,
#          6529: 1,
#          6575: 1,
#          6649: 1,
#          6669: 1,
#          6692: 2,
#          6695: 1,
#          6795: 1,
#          6849: 1,
#          6855: 1,
#          6918: 1,
#          6938: 1,
#          6989: 1,
#          7053: 1,
#          7099: 1,
#          7126: 1,
#          7129: 1,
#          7198: 1,
#          7295: 2,
#          7299: 1,
#          7349: 1,
#          7395: 1,
#          7463: 1,
#          7499: 1,
#          7603: 1,
#          7609: 2,
#          7689: 1,
#          7738: 1,
#          7775: 2,
#          7788: 1,
#          7799: 1,
#          7895: 1,
#          7898: 2,
#          7957: 2,
#          7975: 1,
#          7995: 1,
#          7999: 1,
#          8013: 1,
#          8058: 1,
#          8189: 1,
#          8195: 1,
#          8238: 1,
#          8249: 1,
#          8358: 1,
#          8449: 1,
#          8495: 2,
#          8499: 1,
#          8778: 1,
#          8845: 2,
#          8921: 2,
#          8948: 1,
#          8949: 1,
#          9095: 1,
#          9233: 1,
#          9258: 1,
#          9279: 2,
#          9298: 1,
#          9495: 1,
#          9538: 1,
#          9549: 1,
#          9639: 1,
#          9959: 1,
#          9960: 1,
#          9980: 1,
#          9988: 1,
#          9989: 1,
#          9995: 1,
#          10198: 1,
#          10245: 1,
#          10295: 1,
#          10345: 1,
#          10595: 1,
#          10698: 1,
#          10898: 1,
#          11199: 1,
#          11245: 1,
#          11248: 1,
#          11259: 1,
#          11549: 1,
#          11694: 1,
#          11850: 1,
#          11900: 1,
#          12170: 1,
#          12940: 1,
#          12945: 1,
#          12964: 1,
#          13200: 1,
#          13415: 1,
#          13499: 2,
#          13950: 1,
#          14399: 1,
#          15040: 1,
#          15510: 1,
#          15580: 1,
#          15690: 1,
#          15985: 1,
#          15998: 1,
#          16430: 1,
#          16515: 1,
#          16558: 1,
#          16630: 1,
#          16845: 1,
#          16900: 1,
#          16925: 1,
#          17199: 1,
#          17450: 1,
#          17669: 1,
#          17710: 1,
#          17950: 1,
#          18150: 2,
#          18280: 1,
#          18399: 1,
#          18420: 1,
#          18620: 1,
#          18950: 1,
#          19045: 1,
#          19699: 1,
#          20970: 1,
#          21105: 1,
#          21485: 1,
#          22018: 1,
#          22470: 1,
#          22625: 1,
#          23875: 1,
#          25552: 1,
#          28176: 1,
#          28248: 1,
#          31600: 1,
#          32250: 1,
#          35056: 1})

# %%
np.where(np.array([1,2,3,4,4])==1)[0][0]
# Out:
# 0

# %%
good_predicted_dids = set()

# %%
good_predicted_dids.add(1)

# %%
d1
# Out:
# array([[[-10., -10., -10., ..., -10., -10., -10.],
#         [ -9.,  -9., -10., ..., -10.,  -9.,  -9.]],
#
#        [[-10., -10., -10., ..., -10., -10., -10.],
#         [-10., -10., -10., ..., -10., -10., -10.]],
#
#        [[-10., -10., -10., ..., -10., -10., -10.],
#         [ -9.,  -9., -10., ..., -10.,  -9.,  -9.]],
#
#        ...,
#        [[-10., -10., -10., ..., -10., -10., -10.],
#         [ -9., -10., -10., ..., -10., -10.,  -9.]],
#
#        [[-10., -10., -10., ..., -10., -10., -10.],
#         [-10., -10., -10., ..., -10., -10., -10.]],
#
#        [[-10., -10., -10., ..., -10., -10., -10.],
#         [-10., -10., -10., ..., -10., -10., -10.]]])

# %%
datasets.columns
# Out:
# Index(['MajorityClassSize', 'MaxNominalAttDistinctValues', 'MinorityClassSize',
#        'NumberOfClasses', 'NumberOfFeatures', 'NumberOfInstances',
#        'NumberOfInstancesWithMissingValues', 'NumberOfMissingValues',
#        'NumberOfNumericFeatures', 'NumberOfSymbolicFeatures', 'did', 'format',
#        'name', 'status'],
#       dtype='object')

# %%
datasets[datasets['NumberOfClasses'] == 2]\
        [datasets["NumberOfNumericFeatures"]>0]\
        [datasets["MinorityClassSize"]>100]\
        [datasets["NumberOfNumericFeatures"]<5]\
        [datasets["NumberOfMissingValues"] == 0]["did"].values
# Out:
# C:\Users\Andrea\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# array([161, 162, 464, 724, 741, 772, 774, 795, 811, 814, 827, 860, 914,
#        923, 925, 931, 934, 948, 983, 997, 1169, 1182, 1460, 1462, 1464,
#        1470, 1502, 40698, 40704], dtype=object)

# %%
datasets[datasets['NumberOfClasses'] == 2]\
        [datasets["NumberOfNumericFeatures"]>0]\
        [datasets["MinorityClassSize"]>100]\
        [datasets["NumberOfNumericFeatures"]<5]\
        [datasets["NumberOfMissingValues"] == 0]
# Out:
# C:\Users\Andrea\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#       MajorityClassSize MaxNominalAttDistinctValues MinorityClassSize  \
# 161              614342                          -1            385658
# 162              614332                          -1            385668
# 464                 125                          -1               125
# 724                 260                           9               208
# 741                 515                           4               509
# 772                1209                          -1               969
# 774                 345                          -1               317
# 795                 335                          -1               327
# 811                 163                          12               101
# 814                 256                          -1               212
# 827                 333                          -1               329
# 860                 195                          -1               185
# 914                1519                          -1               482
# 923                4753                           2              3888
# 925                 175                          -1               148
# 931                 348                          -1               314
# 934                 900                          17               256
# 948                1209                          -1               969
# 983                 844                           4               629
# 997                 337                          -1               288
# 1169             299119                         293            240264
# 1182             759864                         NaN            240136
# 1460               2924                         NaN              2376
# 1462                762                          -1               610
# 1464                570                          -1               178
# 1470                290                         NaN               210
# 1502             194198                           2             50859
# 40698               458                         NaN               241
# 40704              1490                         NaN               711
#
#       NumberOfClasses NumberOfFeatures NumberOfInstances  \
# 161                 2                4           1000000
# 162                 2                4           1000000
# 464                 2                3               250
# 724                 2                4               468
# 741                 2                3              1024
# 772                 2                4              2178
# 774                 2                4               662
# 795                 2                4               662
# 811                 2                3               264
# 814                 2                3               468
# 827                 2                4               662
# 860                 2                3               380
# 914                 2                3              2001
# 923                 2                5              8641
# 925                 2                5               323
# 931                 2                4               662
# 934                 2                6              1156
# 948                 2                4              2178
# 983                 2               10              1473
# 997                 2                5               625
# 1169                2                8            539383
# 1182                2               15           1000000
# 1460                2                3              5300
# 1462                2                5              1372
# 1464                2                5               748
# 1470                2               13               500
# 1502                2                4            245057
# 40698               2               11               699
# 40704               2                4              2201
#
#       NumberOfInstancesWithMissingValues NumberOfMissingValues  \
# 161                                    0                     0
# 162                                    0                     0
# 464                                    0                     0
# 724                                    0                     0
# 741                                    0                     0
# 772                                    0                     0
# 774                                    0                     0
# 795                                    0                     0
# 811                                    0                     0
# 814                                    0                     0
# 827                                    0                     0
# 860                                    0                     0
# 914                                    0                     0
# 923                                    0                     0
# 925                                    0                     0
# 931                                    0                     0
# 934                                    0                     0
# 948                                    0                     0
# 983                                    0                     0
# 997                                    0                     0
# 1169                                   0                     0
# 1182                                   0                     0
# 1460                                   0                     0
# 1462                                   0                     0
# 1464                                   0                     0
# 1470                                   0                     0
# 1502                                   0                     0
# 40698                                  0                     0
# 40704                                  0                     0
#
#       NumberOfNumericFeatures NumberOfSymbolicFeatures    did format  \
# 161                         3                        1    161   ARFF
# 162                         3                        1    162   ARFF
# 464                         2                        1    464   ARFF
# 724                         2                        2    724   ARFF
# 741                         1                        2    741   ARFF
# 772                         3                        1    772   ARFF
# 774                         3                        1    774   ARFF
# 795                         3                        1    795   ARFF
# 811                         1                        2    811   ARFF
# 814                         2                        1    814   ARFF
# 827                         3                        1    827   ARFF
# 860                         2                        1    860   ARFF
# 914                         2                        1    914   ARFF
# 923                         3                        2    923   ARFF
# 925                         4                        1    925   ARFF
# 931                         3                        1    931   ARFF
# 934                         1                        5    934   ARFF
# 948                         3                        1    948   ARFF
# 983                         2                        8    983   ARFF
# 997                         4                        1    997   ARFF
# 1169                        3                        5   1169   ARFF
# 1182                        2                       13   1182   ARFF
# 1460                        2                        1   1460   ARFF
# 1462                        4                        1   1462   ARFF
# 1464                        4                        1   1464   ARFF
# 1470                        1                       12   1470   ARFF
# 1502                        3                        1   1502   ARFF
# 40698                       2                        9  40698   ARFF
# 40704                       3                        1  40704   ARFF
#
#                                    name  status
# 161                             SEA(50)  active
# 162                          SEA(50000)  active
# 464                          prnn_synth  active
# 724                analcatdata_vineyard  active
# 741                    rmftsa_sleepdata  active
# 772                               quake  active
# 774                   disclosure_x_bias  active
# 795               disclosure_x_tampered  active
# 811                  rmftsa_ctoarrivals  active
# 814                       chscase_vine2  active
# 827                  disclosure_x_noise  active
# 860                              vinnie  active
# 914                             balloon  active
# 923                    visualizing_soil  active
# 925                  visualizing_galaxy  active
# 931                        disclosure_z  active
# 934                              socmob  active
# 948                               quake  active
# 983                                 cmc  active
# 997                       balance-scale  active
# 1169                           airlines  active
# 1182                         BNG(adult)  active
# 1460                             banana  active
# 1462            banknote-authentication  active
# 1464   blood-transfusion-service-center  active
# 1470                      dresses-sales  active
# 1502                  skin-segmentation  active
# 40698                            breast  active
# 40704                           titanic  active

# %%
datasets.ix[827]
# Out:
# MajorityClassSize                                    333
# MaxNominalAttDistinctValues                           -1
# MinorityClassSize                                    329
# NumberOfClasses                                        2
# NumberOfFeatures                                       4
# NumberOfInstances                                    662
# NumberOfInstancesWithMissingValues                     0
# NumberOfMissingValues                                  0
# NumberOfNumericFeatures                                3
# NumberOfSymbolicFeatures                               1
# did                                                  827
# format                                              ARFF
# name                                  disclosure_x_noise
# status                                            active
# Name: 827, dtype: object
